# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('top 100 streamed songs.csv')
df.head(1)
# Out:
#                        id                     name  duration  energy  key  \
# 0  4ZtFanR9U6ndgddUvNcjcG  Good 4 U Olivia Rodrigo      2.97   0.664    9
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -5.044     1        0.154         0.335               0.0    0.0849
#
#    valence    tempo  danceability
# 0    0.688  166.928         0.563

# %%
df.describe()
# Out:
#          duration      energy        key    loudness        mode  speechiness  \
# count  100.000000  100.000000  100.00000  100.000000  100.000000   100.000000
# mean     3.404900    0.587650    5.05000   -6.577120    0.560000     0.075461
# std      0.927022    0.168273    3.82542    2.447338    0.498888     0.068065
# min      0.730000    0.157000    0.00000  -14.067000    0.000000     0.025300
# 25%      2.910000    0.477750    1.00000   -7.676250    0.000000     0.036100
# 50%      3.370000    0.609000    5.00000   -6.262500    1.000000     0.051800
# 75%      3.630000    0.707750    8.00000   -4.786750    1.000000     0.080650
# max     10.220000    0.883000   11.00000   -2.724000    1.000000     0.368000
#
#        acousticness  instrumentalness    liveness     valence       tempo  \
# count    100.000000        100.000000  100.000000  100.000000  100.000000
# mean       0.314539          0.070682    0.161737    0.517354  121.548260
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.head(1)
# Out:
#                        id                     name  duration  energy  key  \
# 0  4ZtFanR9U6ndgddUvNcjcG  Good 4 U Olivia Rodrigo      2.97   0.664    9
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -5.044     1        0.154         0.335               0.0    0.0849
#
#    valence    tempo  danceability
# 0    0.688  166.928         0.563

# %%
df.columns
# Out:
# Index(['id', 'name', 'duration', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'danceability'],
#       dtype='object')

# %%
# to conver into numpy
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                         id                                               name  \
# 0   4ZtFanR9U6ndgddUvNcjcG                            Good 4 U Olivia Rodrigo
# 1   5fxyZf6m2xHeSrOzUfcJrq                 Stay The Kid LAROI & Justin Bieber
# 2   5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3   4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4   1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
# ..                     ...                                                ...
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 97  54bFM56PmE4YLRnqpW6Tha                       Therefore I Am Billie Eilish
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
# 99  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
# ...

# %%
df.T
# Out:
#                                        0                                   1   \
# id                 4ZtFanR9U6ndgddUvNcjcG              5fxyZf6m2xHeSrOzUfcJrq
# name              Good 4 U Olivia Rodrigo  Stay The Kid LAROI & Justin Bieber
# duration                             2.97                                 2.3
# energy                              0.664                               0.506
# key                                     9                                   8
# loudness                           -5.044                             -11.275
# mode                                    1                                   1
# speechiness                         0.154                              0.0589
# acousticness                        0.335                               0.379
# instrumentalness                        0                               0.868
# liveness                           0.0849                                0.11
# ...

# %%
df.head(2)
# Out:
#                        id                                name  duration  \
# 0  4ZtFanR9U6ndgddUvNcjcG             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540         0.335             0.000
# 1   0.506    8   -11.275     1       0.0589         0.379             0.868
#
#    liveness  valence    tempo  danceability
# 0    0.0849    0.688  166.928         0.563
# 1    0.1100    0.454  170.054         0.564

# %%
# To set in descending order column
df.sort_index(axis=1,ascending=False).head(2)
# Out:
#    valence    tempo  speechiness                                name  mode  \
# 0    0.688  166.928       0.1540             Good 4 U Olivia Rodrigo     1
# 1    0.454  170.054       0.0589  Stay The Kid LAROI & Justin Bieber     1
#
#    loudness  liveness  key  instrumentalness                      id  energy  \
# 0    -5.044    0.0849    9             0.000  4ZtFanR9U6ndgddUvNcjcG   0.664
# 1   -11.275    0.1100    8             0.868  5fxyZf6m2xHeSrOzUfcJrq   0.506
#
#    duration  danceability  acousticness
# 0      2.97         0.563         0.335
# 1      2.30         0.564         0.379

# %%
df1 = df
# now change in df1 will also reflect in df

df1["id"][0] = 898464
df1.head(2)
# Out:
# C:\Users\DNK133\AppData\Local\Temp/ipykernel_5344/2723731166.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["id"][0] = 898464
#                        id                                name  duration  \
# 0                  898464             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540         0.335             0.000
# 1   0.506    8   -11.275     1       0.0589         0.379             0.868
#
#    liveness  valence    tempo  danceability
# 0    0.0849    0.688  166.928         0.563
# 1    0.1100    0.454  170.054         0.564

# %%
df.head(2)
# Out:
#                        id                                name  duration  \
# 0                  898464             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540         0.335             0.000
# 1   0.506    8   -11.275     1       0.0589         0.379             0.868
#
#    liveness  valence    tempo  danceability
# 0    0.0849    0.688  166.928         0.563
# 1    0.1100    0.454  170.054         0.564

# %%
df.loc[0,"id"]= "unique"
df1.head(2)
# Out:
#                        id                                name  duration  \
# 0                  unique             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540         0.335             0.000
# 1   0.506    8   -11.275     1       0.0589         0.379             0.868
#
#    liveness  valence    tempo  danceability
# 0    0.0849    0.688  166.928         0.563
# 1    0.1100    0.454  170.054         0.564

# %%
df.head(2)
# Out:
#                        id                                name  duration  \
# 0                  unique             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540         0.335             0.000
# 1   0.506    8   -11.275     1       0.0589         0.379             0.868
#
#    liveness  valence    tempo  danceability
# 0    0.0849    0.688  166.928         0.563
# 1    0.1100    0.454  170.054         0.564

# %%
# to drop a column
ndf=df.drop("danceability",axis=1).head(2)
ndf
# Out:
#                        id                                name  duration  \
# 0                  unique             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540         0.335             0.000
# 1   0.506    8   -11.275     1       0.0589         0.379             0.868
#
#    liveness  valence    tempo
# 0    0.0849    0.688  166.928
# 1    0.1100    0.454  170.054

# %%
df.loc[[1,2],["key","mode"]]
# Out:
#    key  mode
# 1    8     1
# 2    6     0

# %%
df[(df["key"]>9)].head(4)
# Out:
#                         id                                               name  \
# 7   5wANPM4fQCJwkGd4rN57mH                     drivers license Olivia Rodrigo
# 13  5zFglKYiknIxks8geR8rcL  Beautiful Mistakes (feat. Megan Thee Stallion)...
# 15  02MWAaffLxlfxAUY7c5dvx                           Heat Waves Glass Animals
# 21  5rZlwNFl01HqLWBQGryKSm             Mood Swings (feat. Lil Tjay) Pop Smoke
#
#     duration  energy  key  loudness  mode  speechiness  acousticness  \
# 7       4.03   0.431   10    -8.810     1       0.0578        0.7680
# 13      3.79   0.676   10    -5.483     1       0.0270        0.0377
# 15      3.98   0.525   11    -6.900     1       0.0944        0.4400
# 21      3.56   0.602   10    -6.335     0       0.3680        0.4870
#
#     instrumentalness  liveness  valence    tempo  danceability
# 7           0.000014    0.1060    0.137  143.875         0.561
# 13          0.000000    0.1540    0.721   99.048         0.713
# ...

# %%
df.loc[(df["key"]>9) & (df["duration"]>4)].head(4)
# Out:
#                         id                                             name  \
# 7   5wANPM4fQCJwkGd4rN57mH                   drivers license Olivia Rodrigo
# 91  5wANPM4fQCJwkGd4rN57mH                   drivers license Olivia Rodrigo
# 94  7oD0hfEoijJtSXj7fblDor  Levitating - The Blessed Madonna Remix Dua Lipa
#
#     duration  energy  key  loudness  mode  speechiness  acousticness  \
# 7       4.03   0.431   10    -8.810     1       0.0578        0.7680
# 91      4.03   0.431   10    -8.810     1       0.0578        0.7680
# 94      4.06   0.457   11   -11.026     1       0.0767        0.0919
#
#     instrumentalness  liveness  valence    tempo  danceability
# 7           0.000014    0.1060    0.137  143.875         0.561
# 91          0.000014    0.1060    0.137  143.875         0.561
# 94          0.850000    0.0789    0.566  116.001         0.736
