# %%
import pandas as pd

# %%
df = pd.read_csv("weather.csv")
df
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
df1=df.melt(id_vars=["element"])
df1
# Out:
#     element variable    value
# 0      tmax       id  MX17004
# 1      tmin       id  MX17004
# 2      tmax       id  MX17004
# 3      tmin       id  MX17004
# 4      tmax       id  MX17004
# ..      ...      ...      ...
# 743    tmin      d31      NaN
# 744    tmax      d31      NaN
# 745    tmin      d31      NaN
# 746    tmax      d31      NaN
# 747    tmin      d31      NaN
#
# [748 rows x 3 columns]

# %%
df1[df1["variable"]=="d30"]
# Out:
#     element variable value
# 704    tmax      d30  27.8
# 705    tmin      d30  14.5
# 706    tmax      d30   NaN
# 707    tmin      d30   NaN
# 708    tmax      d30   NaN
# 709    tmin      d30   NaN
# 710    tmax      d30   NaN
# 711    tmin      d30   NaN
# 712    tmax      d30   NaN
# 713    tmin      d30   NaN
# 714    tmax      d30   NaN
# 715    tmin      d30   NaN
# 716    tmax      d30   NaN
# 717    tmin      d30   NaN
# 718    tmax      d30   NaN
# 719    tmin      d30   NaN
# 720    tmax      d30   NaN
# 721    tmin      d30   NaN
# 722    tmax      d30   NaN
# 723    tmin      d30   NaN
# 724    tmax      d30   NaN
# 725    tmin      d30   NaN

# %%
df1=df.melt(id_vars=["element"],var_name="Name",value_name="something")
df1
# Out:
#     element Name something
# 0      tmax   id   MX17004
# 1      tmin   id   MX17004
# 2      tmax   id   MX17004
# 3      tmin   id   MX17004
# 4      tmax   id   MX17004
# ..      ...  ...       ...
# 743    tmin  d31       NaN
# 744    tmax  d31       NaN
# 745    tmin  d31       NaN
# 746    tmax  d31       NaN
# 747    tmin  d31       NaN
#
# [748 rows x 3 columns]

# %%
# %pip install xlrd
# Out:
# ...
#      -------------------------------------- 96.5/96.5 kB 112.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df= pd.read_excel("survey.xls")
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality,[df.Sex,df.Handedness])
# Out:
# Sex         Female       Male
# Handedness    Left Right Left Right
# Nationality
# Bangadesh        1     0    1     0
# China            1     1    1     0
# India            0     0    2     1
# USA              0     2    1     1

# %%
# average age of left and right hand person bades on nationality
import numpy as np
pd.crosstab(df.Nationality,df.Handedness,values = df.Age,aggfunc = np.average)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh    28.0    NaN
# China        50.5   52.0
# India        33.0   37.0
# USA          22.0   20.0
