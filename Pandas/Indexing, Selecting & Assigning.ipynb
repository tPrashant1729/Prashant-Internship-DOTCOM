# %%
import pandas as pd

# %%
mov = pd.read_csv("imdb-top-1000.csv")
mov = pd.DataFrame(mov)

mov.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
# To see a column
mov.Director.head()
# Out:
# 0          Frank Darabont
# 1    Francis Ford Coppola
# 2       Christopher Nolan
# 3    Francis Ford Coppola
# 4            Sidney Lumet
# Name: Director, dtype: object

# %%
mov["Director"].head()
# Out:
# 0          Frank Darabont
# 1    Francis Ford Coppola
# 2       Christopher Nolan
# 3    Francis Ford Coppola
# 4            Sidney Lumet
# Name: Director, dtype: object

# %%
mov["Director"][2]
# Out:
# 'Christopher Nolan'

# %% [markdown]
# # Indexing in pandas

# %% [raw]
# Both loc and iloc are row-first, column-second.
# This is the opposite of what we do in native Python, which is column-first, row-second.

# %%
mov.iloc[0]
# Out:
# Series_Title     The Shawshank Redemption
# Released_Year                        1994
# Runtime                               142
# Genre                               Drama
# IMDB_Rating                           9.3
# Director                   Frank Darabont
# Star1                         Tim Robbins
# No_of_Votes                       2343110
# Gross                         2.83415e+07
# Metascore                              80
# Name: 0, dtype: object

# %%
mov.iloc[:,0].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# Name: Series_Title, dtype: object

# %%
mov.iloc[:4,0]
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# Name: Series_Title, dtype: object

# %%
mov.iloc[:4,:4]
# Out:
#                Series_Title Released_Year  Runtime   Genre
# 0  The Shawshank Redemption          1994      142   Drama
# 1             The Godfather          1972      175   Crime
# 2           The Dark Knight          2008      152  Action
# 3    The Godfather: Part II          1974      202   Crime

# %%
# It's also possible to pass a list:
mov.iloc[[6,2,3],:3]
# Out:
#              Series_Title Released_Year  Runtime
# 6            Pulp Fiction          1994      154
# 2         The Dark Knight          2008      152
# 3  The Godfather: Part II          1974      202

# %%
mov.iloc[:0] # :))
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime, Genre, IMDB_Rating, Director, Star1, No_of_Votes, Gross, Metascore]
# Index: []

# %%
mov.iloc[-1:]
# Out:
#      Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 999  The 39 Steps          1935       86  Crime          7.6
#
#              Director         Star1  No_of_Votes        Gross  Metascore
# 999  Alfred Hitchcock  Robert Donat        51853  302787539.0       93.0

# %% [markdown]
# # Label-based selection

# %% [raw]
# The second paradigm for attribute selection is the one followed by the loc operator:
# label-based selection. In this paradigm, it's the data index value, not its position,
# which matters.

# %%
mov.loc[0,"Director"]
# Out:
# 'Frank Darabont'

# %%
mov.loc[:4,["Director","Series_Title","Genre"]]
# Out:
#                Director              Series_Title   Genre
# 0        Frank Darabont  The Shawshank Redemption   Drama
# 1  Francis Ford Coppola             The Godfather   Crime
# 2     Christopher Nolan           The Dark Knight  Action
# 3  Francis Ford Coppola    The Godfather: Part II   Crime
# 4          Sidney Lumet              12 Angry Men   Crime

# %% [markdown]
# # Manipulating the index

# %%
mov.set_index("IMDB_Rating").head(3)
# Out:
#                          Series_Title Released_Year  Runtime   Genre  \
# IMDB_Rating
# 9.3          The Shawshank Redemption          1994      142   Drama
# 9.2                     The Godfather          1972      175   Crime
# 9.0                   The Dark Knight          2008      152  Action
#
#                          Director           Star1  No_of_Votes        Gross  \
# IMDB_Rating
# 9.3                Frank Darabont     Tim Robbins      2343110   28341469.0
# 9.2          Francis Ford Coppola   Marlon Brando      1620367  134966411.0
# 9.0             Christopher Nolan  Christian Bale      2303232  534858444.0
#
#              Metascore
# IMDB_Rating
# 9.3               80.0
# 9.2              100.0
# 9.0               84.0

# %% [markdown]
# # Conditional selection

# %%
mov.Genre == "Comedy"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Genre, Length: 1000, dtype: bool

# %%
mov.loc[mov.Director == "Rajkumar Hirani"]
# Out:
#              Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 64               3 Idiots          2009      170  Comedy          8.4
# 207                    PK          2014      153  Comedy          8.1
# 233  Lage Raho Munna Bhai          2006      144  Comedy          8.1
# 238   Munna Bhai M.B.B.S.          2003      156  Comedy          8.1
#
#             Director        Star1  No_of_Votes       Gross  Metascore
# 64   Rajkumar Hirani   Aamir Khan       344445   6532908.0       67.0
# 207  Rajkumar Hirani   Aamir Khan       163061  10616104.0        NaN
# 233  Rajkumar Hirani  Sanjay Dutt        43137   2217561.0        NaN
# 238  Rajkumar Hirani  Sanjay Dutt        73992  43851222.0        NaN

# %%
mov.loc[(mov.Genre == "Action") & (mov.IMDB_Rating>8.0)]
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# 14                                          The Matrix          1999      136
# 16      Star Wars: Episode V - The Empire Strikes Back          1980      124
# 29                                           Star Wars          1977      121
# 30                                             Seppuku          1962      133
# 31                                Shichinin no samurai          1954      207
# 39                                           Gladiator          2000      155
# ...

# %%
mov.loc[mov.Genre.isin(['Drama',"Comedy"])]
# Out:
#                         Series_Title Released_Year  Runtime   Genre  \
# 0           The Shawshank Redemption          1994      142   Drama
# 9                         Fight Club          1999      139   Drama
# 11                      Forrest Gump          1994      142   Drama
# 17   One Flew Over the Cuckoo's Nest          1975      133   Drama
# 19                      Gisaengchung          2019      132  Comedy
# ..                               ...           ...      ...     ...
# 994               A Hard Day's Night          1964       87  Comedy
# 995           Breakfast at Tiffany's          1961      115  Comedy
# 996                            Giant          1956      201   Drama
# 997            From Here to Eternity          1953      118   Drama
# 998                         Lifeboat          1944       97   Drama
#
#      IMDB_Rating          Director              Star1  No_of_Votes  \
# 0            9.3    Frank Darabont        Tim Robbins      2343110
# ...

# %%
# to get unique values of column
mov["Genre"].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Fantasy', 'Family', 'Thriller'], dtype=object)

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.2+ KB

# %%
mov.describe()
# Out:
#            Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  843.000000
# mean    122.891000     7.949300  2.736929e+05  1.282781e+08   77.971530
# std      28.093671     0.275491  3.273727e+05  2.011110e+08   12.376099
# min      45.000000     7.600000  2.508800e+04  1.305000e+03   28.000000
# 25%     103.000000     7.700000  5.552625e+04  5.012919e+06   70.000000
# 50%     119.000000     7.900000  1.385485e+05  3.953432e+07   79.000000
# 75%     137.000000     8.100000  3.741612e+05  1.615997e+08   87.000000
# max     321.000000     9.300000  2.343110e+06  9.366622e+08  100.000000

# %%
mov.corr()
# Out:
#               Runtime  IMDB_Rating  No_of_Votes     Gross  Metascore
# Runtime      1.000000     0.243096     0.173264 -0.014531  -0.031452
# IMDB_Rating  0.243096     1.000000     0.494979  0.049824   0.268531
# No_of_Votes  0.173264     0.494979     1.000000  0.085754  -0.018507
# Gross       -0.014531     0.049824     0.085754  1.000000   0.028382
# Metascore   -0.031452     0.268531    -0.018507  0.028382   1.000000

# %%
mov.loc[mov.Metascore.isnull()]
# Out:
#                       Series_Title Released_Year  Runtime      Genre  \
# 20                 Soorarai Pottru          2020      153      Drama
# 54       Ayla: The Daughter of War          2017      125  Biography
# 55                    Vikram Vedha          2017      147     Action
# 57                          Dangal          2016      161     Action
# 65                Taare Zameen Par          2007      165      Drama
# ..                             ...           ...      ...        ...
# 872  The Day the Earth Stood Still          1951       92      Drama
# 874                          Gilda          1946      110      Drama
# 899                      El cuerpo          2012      112    Mystery
# 909                      Celda 211          2009      113     Action
# 913                      Die Welle          2008      107      Drama
#
#      IMDB_Rating       Director           Star1  No_of_Votes        Gross  \
# ...

# %%
mov.loc[mov.Metascore.notnull()]
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %% [markdown]
# # Assigning data

# %%
mov["Runtime"]=100
mov.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      100   Drama          9.3
# 1             The Godfather          1972      100   Crime          9.2
# 2           The Dark Knight          2008      100  Action          9.0
# 3    The Godfather: Part II          1974      100   Crime          9.0
# 4              12 Angry Men          1957      100   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
# changing postion of column
mov["Backward_index"]=range(len(mov),0,-1)
mov.iloc[:5,:5:-1]
# Out:
#    Backward_index  Metascore        Gross  No_of_Votes           Star1
# 0            1000       80.0   28341469.0      2343110     Tim Robbins
# 1             999      100.0  134966411.0      1620367   Marlon Brando
# 2             998       84.0  534858444.0      2303232  Christian Bale
# 3             997       90.0   57300000.0      1129952       Al Pacino
# 4             996       96.0    4360000.0       689845     Henry Fonda

# %% [markdown]
# # Exercise

# %%
mov.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      100   Drama          9.3
# 1             The Godfather          1972      100   Crime          9.2
# 2           The Dark Knight          2008      100  Action          9.0
# 3    The Godfather: Part II          1974      100   Crime          9.0
# 4              12 Angry Men          1957      100   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore  \
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0
#
#    Backward_index
# 0            1000
# 1             999
# ...

# %%
# select col and assign to one var
imdb = mov["IMDB_Rating"]
imdb.head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.0
# 3    9.0
# 4    9.0
# Name: IMDB_Rating, dtype: float64

# %%
# Select the first value from the Director column of `mov`,
# assigning it to variable `first_director`.

first_director = mov.loc[0,"Director"]
first_director
# Out:
# 'Frank Darabont'

# %%
#Select the first row of data (the first record) from `mov`,
# assigning it to the variable `first_row`.
first_row = mov.loc[0]
first_row
# Out:
# Series_Title      The Shawshank Redemption
# Released_Year                         1994
# Runtime                                100
# Genre                                Drama
# IMDB_Rating                            9.3
# Director                    Frank Darabont
# Star1                          Tim Robbins
# No_of_Votes                        2343110
# Gross                          2.83415e+07
# Metascore                               80
# Backward_index                        1000
# Name: 0, dtype: object

# %%
# Select the first 10 values from the Star1 column in mov,
# assigning the result to variable first_Star1.

first_Star1 = mov.loc[:10,"Star1"]
first_Star1 = pd.Series(first_Star1)
first_Star1
# Out:
# 0           Tim Robbins
# 1         Marlon Brando
# 2        Christian Bale
# 3             Al Pacino
# 4           Henry Fonda
# 5           Elijah Wood
# 6         John Travolta
# 7           Liam Neeson
# 8     Leonardo DiCaprio
# 9             Brad Pitt
# 10          Elijah Wood
# Name: Star1, dtype: object

# %%
# Select the records with index labels 1, 2, 3, 5, and 8,
# assigning the result to the variable sample_reviews.
sample_reviews = mov.iloc[[1,2,3,5,8],:]
sample_reviews
# Out:
#                                     Series_Title Released_Year  Runtime  \
# 1                                  The Godfather          1972      100
# 2                                The Dark Knight          2008      100
# 3                         The Godfather: Part II          1974      100
# 5  The Lord of the Rings: The Return of the King          2003      100
# 8                                      Inception          2010      100
#
#     Genre  IMDB_Rating              Director              Star1  No_of_Votes  \
# 1   Crime          9.2  Francis Ford Coppola      Marlon Brando      1620367
# 2  Action          9.0     Christopher Nolan     Christian Bale      2303232
# 3   Crime          9.0  Francis Ford Coppola          Al Pacino      1129952
# 5  Action          8.9         Peter Jackson        Elijah Wood      1642758
# 8  Action          8.8     Christopher Nolan  Leonardo DiCaprio      2067042
#
#          Gross  Metascore  Backward_index
# ...

# %%
# Create a variable df containing the country, province, region_1, and region_2 columns
# of the records with the index labels 0, 1, 10, and 100. In other words,
# generate the following DataFrame: column changed as per my data

df = mov.loc[[0,1,10,100],["Series_Title","IMDB_Rating","Genre","Gross"]].sort_values(by="Gross",ascending=False)
df
# Out:
#                                           Series_Title  IMDB_Rating   Genre  \
# 10   The Lord of the Rings: The Fellowship of the Ring          8.8  Action
# 1                                        The Godfather          9.2   Crime
# 0                             The Shawshank Redemption          9.3   Drama
# 100                                  Bacheha-Ye aseman          8.3   Drama
#
#            Gross
# 10   315544750.0
# 1    134966411.0
# 0     28341469.0
# 100     933933.0

# %%
# Create a variable df containing the country and variety columns of the first 100 records.
# column changed as per my data
df = mov.loc[:99,["Series_Title","Director"]]
df
# Out:
#                 Series_Title              Director
# 0   The Shawshank Redemption        Frank Darabont
# 1              The Godfather  Francis Ford Coppola
# 2            The Dark Knight     Christopher Nolan
# 3     The Godfather: Part II  Francis Ford Coppola
# 4               12 Angry Men          Sidney Lumet
# ..                       ...                   ...
# 95                    Amélie    Jean-Pierre Jeunet
# 96                    Snatch           Guy Ritchie
# 97       Requiem for a Dream      Darren Aronofsky
# 98           American Beauty            Sam Mendes
# 99         Good Will Hunting          Gus Van Sant
#
# [100 rows x 2 columns]

# %%
# Create a DataFrame italian_wines containing reviews of wines made in Italy. 
# Hint: reviews.country equals what?

mov.loc[mov.IMDB_Rating>8.8,"Series_Title"]
# Out:
# 0                         The Shawshank Redemption
# 1                                    The Godfather
# 2                                  The Dark Knight
# 3                           The Godfather: Part II
# 4                                     12 Angry Men
# 5    The Lord of the Rings: The Return of the King
# 6                                     Pulp Fiction
# 7                                 Schindler's List
# Name: Series_Title, dtype: object

# %%
mov = pd.read_csv("imdb-top-1000.csv")
mov
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
# Create a DataFrame top_oceania_wines containing all reviews with at least
# 95 points (out of 100) for wines from Australia or New Zealand.
# this is different concept

mov[mov["IMDB_Rating"]>8.0][["Series_Title","IMDB_Rating","Genre"]].groupby("Genre").sum()["IMDB_Rating"].sort_values(ascending=False)
# Out:
# Genre
# Drama        832.7
# Action       433.0
# Crime        350.6
# Comedy       320.4
# Biography    222.8
# Animation    206.0
# Adventure    188.7
# Mystery       41.4
# Western       25.6
# Horror        25.0
# Film-Noir      8.1
# Fantasy        8.1
# Name: IMDB_Rating, dtype: float64

# %%
mov[(mov["IMDB_Rating"]>8.0) | (mov.Genre == "Comedy")]
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 0                          The Shawshank Redemption          1994      142
# 1                                     The Godfather          1972      175
# 2                                   The Dark Knight          2008      152
# 3                            The Godfather: Part II          1974      202
# 4                                      12 Angry Men          1957       96
# ..                                              ...           ...      ...
# 977  The Naked Gun: From the Files of Police Squad!          1988       85
# 978                    Planes, Trains & Automobiles          1987       93
# 989                                The Long Goodbye          1973      112
# 994                              A Hard Day's Night          1964       87
# 995                          Breakfast at Tiffany's          1961      115
#
# ...
