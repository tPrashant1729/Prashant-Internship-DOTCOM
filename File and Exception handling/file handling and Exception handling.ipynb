# %%
try:
    print(10/0)
    
except ZeroDivisionError:
    print("denominator can't be zero")
# Out:
# denominator can't be zero

# %% [markdown]
# ![error.PNG](attachment:error.PNG)

# %%
try:
    a=[1,2,3,4,5]
    print(a[3])
#     print(a[6])
except IndexError:
    print("index out of range")
else:
    print(a[3],"is divesible by 2")
finally:
    print("I will be always executed :)")
# Out:
# 4
# 4 is divesible by 2
# I will be always executed :)

# %% [markdown]
# File Handling

# %%
with open("C://Users//DNK133//Desktop/vs code/open.txt","r") as file:
#     file.write("welcome to open.txt")
#    
    print(file.read(7))
# Out:
# welcome

# %%
with open("C://Users//DNK133//Desktop/vs code/open.txt","r") as file:

    print(file.readlines())
# Out:
# ['welcome to open.txt']

# %%
import os

if os.path.exists("C://Users//DNK133//Desktop/vs code/p.txt"):
    with open("C://Users//DNK133//Desktop/vs code/r.txt","w"):
        pass
    os.remove("C://Users//DNK133//Desktop/vs code/r.txt")
    print("deleted")
# Out:
# deleted
